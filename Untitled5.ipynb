# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a4924ae-b07c-4833-948a-b45c3bdc6d63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a4924ae-b07c-4833-948a-b45c3bdc6d63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('./data.csv')
df.head(5)
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# ...

# %%
df.shape
# Out:
# (6810, 12)

# %%
df.tail(10)
# Out:
#              isbn13      isbn10  \
# 6800  9788125026600  8125026606
# 6801  9788171565641  8171565646
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6806  9788185944609  8185944601
# 6807  9788445074879  8445074873
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 6800                            Nietzsche For Beginners
# 6801                               Aspects of the Novel
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# 6806                               Secrets Of The Heart
# 6807                                     Fahrenheit 451
# 6808                           The Berlin Phenomenology
# ...

# %%
sns.countplot(data=df, x='published_year')
df['title'].value_counts()
# Out:
# The Lord of the Rings            11
# Three Complete Novels             8
# Star Wars                         7
# One Hundred Years of Solitude     6
# The Fellowship of the Ring        5
#                                  ..
# House of Leaves                   1
# Moral Disorder                    1
# D. B.                             1
# Waterfront                        1
# 'I'm Telling You Stories'         1
# Name: title, Length: 6398, dtype: int64

# %%
df['published_year'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='published_year'>

# %%
# greater than 2000
df_filtered = df[df['published_year'] > 2000]

df_filtered['published_year'].value_counts().plot(kind='pie', autopct='%0.2f%%')

# To display the plot
plt.show()

# %%
# Histogram
df_filtered = df[df['published_year'] > 1900]
plt.hist(df['published_year'])

# represents no. of books in the given publication year
# Out:
# (array([1.000e+00, 2.000e+00, 1.000e+00, 2.000e+00, 9.000e+00, 3.300e+01,
#         1.430e+02, 3.610e+02, 3.135e+03, 3.117e+03]),
#  array([1853. , 1869.6, 1886.2, 1902.8, 1919.4, 1936. , 1952.6, 1969.2,
#         1985.8, 2002.4, 2019. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['published_year'])
# Out:
# <ipython-input-18-425662c3c2d2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['published_year'])
# <Axes: xlabel='published_year', ylabel='Density'>

# %%
#boxPlot
sns.boxplot(df['published_year'])
# plt.show()
# Out:
# <Axes: ylabel='published_year'>

# %%
df.describe()
# Out:
#              isbn13  published_year  average_rating    num_pages  \
# count  6.810000e+03     6804.000000     6767.000000  6767.000000
# mean   9.780677e+12     1998.630364        3.933284   348.181026
# std    6.068911e+08       10.484257        0.331352   242.376783
# min    9.780002e+12     1853.000000        0.000000     0.000000
# 25%    9.780330e+12     1996.000000        3.770000   208.000000
# 50%    9.780553e+12     2002.000000        3.960000   304.000000
# 75%    9.780810e+12     2005.000000        4.130000   420.000000
# max    9.789042e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count
# count   6.767000e+03
# mean    2.106910e+04
# std     1.376207e+05
# min     0.000000e+00
# 25%     1.590000e+02
# 50%     1.018000e+03
# 75%     5.992500e+03
# max     5.629932e+06

# %%
# for built in dataset
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
flight = sns.load_dataset('flights')
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['month'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# flight['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# flight['passengers'].plot(kind='hist', bins=20, title='passengers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', data=tips)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB

# %%
df.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'subtitle', 'authors', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating',
#        'num_pages', 'ratings_count'],
#       dtype='object')

# %%
# Displot (Distribution Plot)
sns.displot(data=df, x='average_rating', hue='categories', kde=True, multiple="stack")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-6aa96df5f3c3> in <cell line: 2>()
#       1 # Displot (Distribution Plot)
# ----> 2 sns.displot(data=df, x='average_rating', hue='categories', kde=True, multiple="stack")
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2191
#    2192             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193             p.plot_univariate_histogram(**hist_kws)
#    2194
#    2195         else:
#
# ...

# %%
sns.displot(df[df['published_year'] == 2000]['average_rating'], kind='kde', fill=True)
sns.displot(df[df['published_year'] == 1950]['average_rating'], kind='kde', fill=True)

# %%
sns.heatmap(pd.crosstab(df['average_rating'],df['published_year']))
# Out:
# <Axes: xlabel='published_year', ylabel='average_rating'>

# %%
df.groupby('authors').mean()['ratings_count']*100
# Out:
# <ipython-input-50-cb14e02bde96>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('authors').mean()['ratings_count']*100
# authors
# A. Hatto                       389300.0
# A. M. Homes                    213500.0
# A. N. Roquelaure;Anne Rice    2184400.0
# A.J. Meadows                      400.0
# A.N. Roquelaure               1072800.0
#                                 ...
# 川端康成                           590000.0
# 村上真美子                            2700.0
# 村上龍                            556000.0
# 武蔵·宮本                           43000.0
# 紫式部                              4600.0
# Name: ratings_count, Length: 3780, dtype: float64

# %%
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.pairplot(iris,hue='species')

# %%
# lineplot
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips,hue='day')

# %%
new = flight.groupby("year").sum(numeric_only=True).reset_index()

# %%
new_books = df.groupby("published_year").sum(numeric_only=True).reset_index()

# %%
sns.lineplot(x='published_year', y='ratings_count', data=new_books)
# Out:
# <Axes: xlabel='published_year', ylabel='ratings_count'>

# %%
new_books_sorted = new_books.sort_values('published_year')

# %%
new_books = new_books_sorted.tail(10)

# %%
sns.heatmap(new_books, annot=True, fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
books_only = new_books_sorted.tail(10)

# %%
# Set the figure size, decrease height
plt.figure(figsize=(10, 5))

# %%
# heatmap
sns.heatmap(books_only, annot=True, fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')

# %%
flights_pivot = flights.pivot_table(values='passengers', index='month', columns='year')

# %%
# Heatmap
sns.heatmap(flights_pivot, annot=True, fmt="d", cmap='coolwarm')
plt.show()
